# %%
#Dependencies
import json
import requests as req
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from citipy import citipy
import random
import time
import re

# %%
#Set up lists to collect data
cities = []
lats = []
temps = []
humid = []
wind = []
clouds = []
frames = []

# %%
#Randomly generate lat/lng and collect nearest city
for i in range(10):
    lat = np.random.uniform(low=-90.00000, high=90.000000, size = 60)
    lng = np.random.uniform(low=-120.00000, high=120.000000, size = 60)
    print ("Please wait, fetching cities")
    time.sleep(60)
    for j in range(50):
        try:
            city = citipy.nearest_city(lat[j], lng[j])
            city_name = city.city_name
            query = re.sub('\s+','+',city_name.lower())
        #API request
            url = "http://api.openweathermap.org/data/2.5/weather?q=" + query + "&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial"
            response = req.get(url)
            print("Retrieving weather data for " + query)
            print(url)
            response_json = response.json()
        #Collect data from JSON 
            temps.append(response_json["main"]["temp"])
            humid.append(response_json["main"]["humidity"])
            wind.append(response_json["wind"]["speed"])
            clouds.append(response_json["clouds"]["all"])
            cities.append(query)
            lats.append(lat[j])
        except KeyError:
            url = "http://api.openweathermap.org/data/2.5/weather?lat=" + str(lat[j]) + "&lon=" + str(lng[j]) + "&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial"
            response = req.get(url)
            print("Trying somewhere near that")
            print(url)
            response_json = response.json()
            temps.append(response_json["main"]["temp"])
            humid.append(response_json["main"]["humidity"])
            wind.append(response_json["wind"]["speed"])
            clouds.append(response_json["clouds"]["all"])
            cities.append(query)
            lats.append(lat[j])
            
df = pd.DataFrame(data = {"Cities": cities, "Latitude": lats, "Temperature": temps, "Humidity": humid, "Wind Speed": wind, "Cloud Cover": clouds})
frames.append(df)
# Out:
# Please wait, fetching cities
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for miraflores
# http://api.openweathermap.org/data/2.5/weather?q=miraflores&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for havelock
# http://api.openweathermap.org/data/2.5/weather?q=havelock&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for east+london
# http://api.openweathermap.org/data/2.5/weather?q=east+london&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for nikki
# http://api.openweathermap.org/data/2.5/weather?q=nikki&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for palabuhanratu
# http://api.openweathermap.org/data/2.5/weather?q=palabuhanratu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-19.223004118&lon=98.0184043582&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for kachug
# http://api.openweathermap.org/data/2.5/weather?q=kachug&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for margate
# http://api.openweathermap.org/data/2.5/weather?q=margate&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for amalapuram
# http://api.openweathermap.org/data/2.5/weather?q=amalapuram&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for shakhtne
# http://api.openweathermap.org/data/2.5/weather?q=shakhtne&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=48.0082644942&lon=38.3916296556&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for omboue
# http://api.openweathermap.org/data/2.5/weather?q=omboue&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for pompeu
# http://api.openweathermap.org/data/2.5/weather?q=pompeu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-74.8999560247&lon=61.122616456&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mortka
# http://api.openweathermap.org/data/2.5/weather?q=mortka&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for sakakah
# http://api.openweathermap.org/data/2.5/weather?q=sakakah&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=28.3183017204&lon=39.9988054563&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for matadi
# http://api.openweathermap.org/data/2.5/weather?q=matadi&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for magadi
# http://api.openweathermap.org/data/2.5/weather?q=magadi&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for nanortalik
# http://api.openweathermap.org/data/2.5/weather?q=nanortalik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for atuona
# http://api.openweathermap.org/data/2.5/weather?q=atuona&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for yerbogachen
# http://api.openweathermap.org/data/2.5/weather?q=yerbogachen&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for gouyave
# http://api.openweathermap.org/data/2.5/weather?q=gouyave&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for vila+franca+do+campo
# http://api.openweathermap.org/data/2.5/weather?q=vila+franca+do+campo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for souillac
# http://api.openweathermap.org/data/2.5/weather?q=souillac&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=79.3232245735&lon=-22.4891138627&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for moron
# http://api.openweathermap.org/data/2.5/weather?q=moron&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for sao+filipe
# http://api.openweathermap.org/data/2.5/weather?q=sao+filipe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for farrukhnagar
# http://api.openweathermap.org/data/2.5/weather?q=farrukhnagar&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for amderma
# http://api.openweathermap.org/data/2.5/weather?q=amderma&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=80.6795888323&lon=65.9687406522&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for starosubkhangulovo
# http://api.openweathermap.org/data/2.5/weather?q=starosubkhangulovo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?q=komsomolskiy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for namibe
# http://api.openweathermap.org/data/2.5/weather?q=namibe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bolshevik
# http://api.openweathermap.org/data/2.5/weather?q=bolshevik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=51.1389066034&lon=41.6851887512&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for kasongo-lunda
# http://api.openweathermap.org/data/2.5/weather?q=kasongo-lunda&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jagdalpur
# http://api.openweathermap.org/data/2.5/weather?q=jagdalpur&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cape+town
# http://api.openweathermap.org/data/2.5/weather?q=cape+town&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Please wait, fetching cities
# Retrieving weather data for hambantota
# http://api.openweathermap.org/data/2.5/weather?q=hambantota&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taltal
# http://api.openweathermap.org/data/2.5/weather?q=taltal&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for karistos
# http://api.openweathermap.org/data/2.5/weather?q=karistos&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=38.1173251961&lon=24.5433772675&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for macroom
# http://api.openweathermap.org/data/2.5/weather?q=macroom&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-50.7029195213&lon=50.6496406385&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for port+alfred
# http://api.openweathermap.org/data/2.5/weather?q=port+alfred&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for saldanha
# http://api.openweathermap.org/data/2.5/weather?q=saldanha&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for diego+de+almagro
# http://api.openweathermap.org/data/2.5/weather?q=diego+de+almagro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for sorland
# http://api.openweathermap.org/data/2.5/weather?q=sorland&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for eyl
# http://api.openweathermap.org/data/2.5/weather?q=eyl&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for kawalu
# http://api.openweathermap.org/data/2.5/weather?q=kawalu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for east+london
# http://api.openweathermap.org/data/2.5/weather?q=east+london&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hay+river
# http://api.openweathermap.org/data/2.5/weather?q=hay+river&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bulgan
# http://api.openweathermap.org/data/2.5/weather?q=bulgan&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for santa+cruz
# http://api.openweathermap.org/data/2.5/weather?q=santa+cruz&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dinsor
# http://api.openweathermap.org/data/2.5/weather?q=dinsor&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=2.43211034037&lon=43.1621009469&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for strelka
# http://api.openweathermap.org/data/2.5/weather?q=strelka&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for gravdal
# http://api.openweathermap.org/data/2.5/weather?q=gravdal&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for maues
# http://api.openweathermap.org/data/2.5/weather?q=maues&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for luderitz
# http://api.openweathermap.org/data/2.5/weather?q=luderitz&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mecca
# http://api.openweathermap.org/data/2.5/weather?q=mecca&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for chizhou
# http://api.openweathermap.org/data/2.5/weather?q=chizhou&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for necochea
# http://api.openweathermap.org/data/2.5/weather?q=necochea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for wahran
# http://api.openweathermap.org/data/2.5/weather?q=wahran&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=33.7667468444&lon=-0.426233024235&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bambous+virieux
# http://api.openweathermap.org/data/2.5/weather?q=bambous+virieux&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for itaituba
# http://api.openweathermap.org/data/2.5/weather?q=itaituba&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for warqla
# http://api.openweathermap.org/data/2.5/weather?q=warqla&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=31.2221455234&lon=7.42542854576&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for husavik
# http://api.openweathermap.org/data/2.5/weather?q=husavik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for port+elizabeth
# http://api.openweathermap.org/data/2.5/weather?q=port+elizabeth&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for zhaotong
# http://api.openweathermap.org/data/2.5/weather?q=zhaotong&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taseyevo
# http://api.openweathermap.org/data/2.5/weather?q=taseyevo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cayenne
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for puerto+ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto+ayora&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Please wait, fetching cities
# Retrieving weather data for karaul
# http://api.openweathermap.org/data/2.5/weather?q=karaul&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=70.5052394658&lon=83.087835963&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dawei
# http://api.openweathermap.org/data/2.5/weather?q=dawei&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for talara
# http://api.openweathermap.org/data/2.5/weather?q=talara&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for benguela
# http://api.openweathermap.org/data/2.5/weather?q=benguela&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tumannyy
# http://api.openweathermap.org/data/2.5/weather?q=tumannyy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=88.812134259&lon=39.8496209308&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for orsha
# http://api.openweathermap.org/data/2.5/weather?q=orsha&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bintulu
# http://api.openweathermap.org/data/2.5/weather?q=bintulu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-32.8213155206&lon=46.004858891&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for leh
# http://api.openweathermap.org/data/2.5/weather?q=leh&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for east+london
# http://api.openweathermap.org/data/2.5/weather?q=east+london&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for nilanga
# http://api.openweathermap.org/data/2.5/weather?q=nilanga&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for phibun+mangsahan
# http://api.openweathermap.org/data/2.5/weather?q=phibun+mangsahan&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bilyayivka
# http://api.openweathermap.org/data/2.5/weather?q=bilyayivka&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for roald
# http://api.openweathermap.org/data/2.5/weather?q=roald&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for husavik
# http://api.openweathermap.org/data/2.5/weather?q=husavik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for nurota
# http://api.openweathermap.org/data/2.5/weather?q=nurota&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for kortkeros
# http://api.openweathermap.org/data/2.5/weather?q=kortkeros&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bengkulu
# http://api.openweathermap.org/data/2.5/weather?q=bengkulu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for kidal
# http://api.openweathermap.org/data/2.5/weather?q=kidal&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-32.2057762698&lon=54.041745657&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for touros
# http://api.openweathermap.org/data/2.5/weather?q=touros&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for khatanga
# http://api.openweathermap.org/data/2.5/weather?q=khatanga&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for santa+ines
# http://api.openweathermap.org/data/2.5/weather?q=santa+ines&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Please wait, fetching cities
# Retrieving weather data for georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for padang
# http://api.openweathermap.org/data/2.5/weather?q=padang&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for arraial+do+cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial+do+cabo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for kantabanji
# http://api.openweathermap.org/data/2.5/weather?q=kantabanji&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for yumen
# http://api.openweathermap.org/data/2.5/weather?q=yumen&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for athens
# http://api.openweathermap.org/data/2.5/weather?q=athens&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-79.8198004922&lon=66.7199894565&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for lumphat
# http://api.openweathermap.org/data/2.5/weather?q=lumphat&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for manono
# http://api.openweathermap.org/data/2.5/weather?q=manono&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cape+town
# http://api.openweathermap.org/data/2.5/weather?q=cape+town&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for puerto+del+rosario
# http://api.openweathermap.org/data/2.5/weather?q=puerto+del+rosario&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rocha
# http://api.openweathermap.org/data/2.5/weather?q=rocha&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cape+town
# http://api.openweathermap.org/data/2.5/weather?q=cape+town&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for port+blair
# http://api.openweathermap.org/data/2.5/weather?q=port+blair&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for varenikovskaya
# http://api.openweathermap.org/data/2.5/weather?q=varenikovskaya&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for upernavik
# http://api.openweathermap.org/data/2.5/weather?q=upernavik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for warqla
# http://api.openweathermap.org/data/2.5/weather?q=warqla&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=27.8376385575&lon=6.51762261308&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-82.117716147&lon=61.1289235746&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for inirida
# http://api.openweathermap.org/data/2.5/weather?q=inirida&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for riyadh
# http://api.openweathermap.org/data/2.5/weather?q=riyadh&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for macapa
# http://api.openweathermap.org/data/2.5/weather?q=macapa&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for pousat
# http://api.openweathermap.org/data/2.5/weather?q=pousat&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=13.1269361912&lon=104.187542992&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tsihombe
# http://api.openweathermap.org/data/2.5/weather?q=tsihombe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-50.3951751573&lon=48.073327522&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for gat
# http://api.openweathermap.org/data/2.5/weather?q=gat&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=24.5018575686&lon=11.5852626666&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for umzimvubu
# http://api.openweathermap.org/data/2.5/weather?q=umzimvubu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-34.7031058629&lon=30.9193353366&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for santiago+atitlan
# http://api.openweathermap.org/data/2.5/weather?q=santiago+atitlan&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for coquimbo
# http://api.openweathermap.org/data/2.5/weather?q=coquimbo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for supe
# http://api.openweathermap.org/data/2.5/weather?q=supe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for alexandria
# http://api.openweathermap.org/data/2.5/weather?q=alexandria&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for elko
# http://api.openweathermap.org/data/2.5/weather?q=elko&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tessalit
# http://api.openweathermap.org/data/2.5/weather?q=tessalit&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taltal
# http://api.openweathermap.org/data/2.5/weather?q=taltal&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Please wait, fetching cities
# Retrieving weather data for los+llanos+de+aridane
# http://api.openweathermap.org/data/2.5/weather?q=los+llanos+de+aridane&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taveta
# http://api.openweathermap.org/data/2.5/weather?q=taveta&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for high+level
# http://api.openweathermap.org/data/2.5/weather?q=high+level&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for east+london
# http://api.openweathermap.org/data/2.5/weather?q=east+london&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for grindavik
# http://api.openweathermap.org/data/2.5/weather?q=grindavik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for sao+lourenco+do+sul
# http://api.openweathermap.org/data/2.5/weather?q=sao+lourenco+do+sul&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cape+town
# http://api.openweathermap.org/data/2.5/weather?q=cape+town&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jashpurnagar
# http://api.openweathermap.org/data/2.5/weather?q=jashpurnagar&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for locri
# http://api.openweathermap.org/data/2.5/weather?q=locri&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=77.6771330851&lon=-12.8892146246&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for george
# http://api.openweathermap.org/data/2.5/weather?q=george&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mayaky
# http://api.openweathermap.org/data/2.5/weather?q=mayaky&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mecca
# http://api.openweathermap.org/data/2.5/weather?q=mecca&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for pisco
# http://api.openweathermap.org/data/2.5/weather?q=pisco&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for muros
# http://api.openweathermap.org/data/2.5/weather?q=muros&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for acacoyagua
# http://api.openweathermap.org/data/2.5/weather?q=acacoyagua&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mochudi
# http://api.openweathermap.org/data/2.5/weather?q=mochudi&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for belushya+guba
# http://api.openweathermap.org/data/2.5/weather?q=belushya+guba&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=89.010716102&lon=47.6394384023&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bongandanga
# http://api.openweathermap.org/data/2.5/weather?q=bongandanga&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jumla
# http://api.openweathermap.org/data/2.5/weather?q=jumla&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bougouni
# http://api.openweathermap.org/data/2.5/weather?q=bougouni&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for pangnirtung
# http://api.openweathermap.org/data/2.5/weather?q=pangnirtung&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for sarishabari
# http://api.openweathermap.org/data/2.5/weather?q=sarishabari&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for puerto+ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto+ayora&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for canapi
# http://api.openweathermap.org/data/2.5/weather?q=canapi&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-9.05316700155&lon=-37.5241454744&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cayenne
# http://api.openweathermap.org/data/2.5/weather?q=cayenne&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hithadhoo
# http://api.openweathermap.org/data/2.5/weather?q=hithadhoo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for lebu
# http://api.openweathermap.org/data/2.5/weather?q=lebu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for laguna
# http://api.openweathermap.org/data/2.5/weather?q=laguna&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for kostomuksha
# http://api.openweathermap.org/data/2.5/weather?q=kostomuksha&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for play+cu
# http://api.openweathermap.org/data/2.5/weather?q=play+cu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=13.7345719293&lon=107.840713505&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bargal
# http://api.openweathermap.org/data/2.5/weather?q=bargal&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=10.2722338707&lon=51.7993563508&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dhari
# http://api.openweathermap.org/data/2.5/weather?q=dhari&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for saint-philippe
# http://api.openweathermap.org/data/2.5/weather?q=saint-philippe&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for pitea
# http://api.openweathermap.org/data/2.5/weather?q=pitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-71.888893846&lon=71.7085804695&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tocopilla
# http://api.openweathermap.org/data/2.5/weather?q=tocopilla&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for calamar
# http://api.openweathermap.org/data/2.5/weather?q=calamar&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Please wait, fetching cities
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cape+coast
# http://api.openweathermap.org/data/2.5/weather?q=cape+coast&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for pio+ix
# http://api.openweathermap.org/data/2.5/weather?q=pio+ix&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?q=vestmannaeyjar&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-31.3073092926&lon=52.0626722141&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for burica
# http://api.openweathermap.org/data/2.5/weather?q=burica&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=7.89224236274&lon=-82.7835614807&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for lensk
# http://api.openweathermap.org/data/2.5/weather?q=lensk&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for marystown
# http://api.openweathermap.org/data/2.5/weather?q=marystown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for trairi
# http://api.openweathermap.org/data/2.5/weather?q=trairi&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dingle
# http://api.openweathermap.org/data/2.5/weather?q=dingle&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for codrington
# http://api.openweathermap.org/data/2.5/weather?q=codrington&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jawhar
# http://api.openweathermap.org/data/2.5/weather?q=jawhar&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for balikpapan
# http://api.openweathermap.org/data/2.5/weather?q=balikpapan&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=80.1433687673&lon=-10.86603427&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for torbay
# http://api.openweathermap.org/data/2.5/weather?q=torbay&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for illoqqortoormiut
# http://api.openweathermap.org/data/2.5/weather?q=illoqqortoormiut&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=88.9986105633&lon=-19.8824082596&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for adrar
# http://api.openweathermap.org/data/2.5/weather?q=adrar&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for barentsburg
# http://api.openweathermap.org/data/2.5/weather?q=barentsburg&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=73.786261392&lon=14.2068952179&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tsienyane
# http://api.openweathermap.org/data/2.5/weather?q=tsienyane&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-21.0859604633&lon=23.7093440901&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tazovskiy
# http://api.openweathermap.org/data/2.5/weather?q=tazovskiy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tasiilaq
# ...
# Retrieving weather data for banmo
# http://api.openweathermap.org/data/2.5/weather?q=banmo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=23.9936541622&lon=96.9854297803&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for baykit
# http://api.openweathermap.org/data/2.5/weather?q=baykit&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for koboko
# http://api.openweathermap.org/data/2.5/weather?q=koboko&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for high+rock
# http://api.openweathermap.org/data/2.5/weather?q=high+rock&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for svetlyy
# http://api.openweathermap.org/data/2.5/weather?q=svetlyy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tabou
# http://api.openweathermap.org/data/2.5/weather?q=tabou&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dikson
# http://api.openweathermap.org/data/2.5/weather?q=dikson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for xinzhou
# http://api.openweathermap.org/data/2.5/weather?q=xinzhou&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for margate
# http://api.openweathermap.org/data/2.5/weather?q=margate&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for san+cristobal
# http://api.openweathermap.org/data/2.5/weather?q=san+cristobal&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tahlequah
# http://api.openweathermap.org/data/2.5/weather?q=tahlequah&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for deloraine
# http://api.openweathermap.org/data/2.5/weather?q=deloraine&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for saskylakh
# http://api.openweathermap.org/data/2.5/weather?q=saskylakh&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for oranjemund
# http://api.openweathermap.org/data/2.5/weather?q=oranjemund&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for north+platte
# http://api.openweathermap.org/data/2.5/weather?q=north+platte&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for vardo
# http://api.openweathermap.org/data/2.5/weather?q=vardo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ilulissat
# http://api.openweathermap.org/data/2.5/weather?q=ilulissat&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ilo
# http://api.openweathermap.org/data/2.5/weather?q=ilo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for louisbourg
# http://api.openweathermap.org/data/2.5/weather?q=louisbourg&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=43.2344008147&lon=-59.4417186047&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for el+progreso
# http://api.openweathermap.org/data/2.5/weather?q=el+progreso&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for boulsa
# http://api.openweathermap.org/data/2.5/weather?q=boulsa&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for puerto+ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto+ayora&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for catamarca
# http://api.openweathermap.org/data/2.5/weather?q=catamarca&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-29.6524545867&lon=-64.4860766374&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for iskateley
# http://api.openweathermap.org/data/2.5/weather?q=iskateley&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ancud
# http://api.openweathermap.org/data/2.5/weather?q=ancud&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for eidfjord
# http://api.openweathermap.org/data/2.5/weather?q=eidfjord&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bubaque
# http://api.openweathermap.org/data/2.5/weather?q=bubaque&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for klaksvik
# http://api.openweathermap.org/data/2.5/weather?q=klaksvik&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for chuy
# http://api.openweathermap.org/data/2.5/weather?q=chuy&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for hermanus
# http://api.openweathermap.org/data/2.5/weather?q=hermanus&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mar+del+plata
# http://api.openweathermap.org/data/2.5/weather?q=mar+del+plata&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ponta+do+sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta+do+sol&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ushuaia
# http://api.openweathermap.org/data/2.5/weather?q=ushuaia&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for camana
# http://api.openweathermap.org/data/2.5/weather?q=camana&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for verkhnyaya+salda
# http://api.openweathermap.org/data/2.5/weather?q=verkhnyaya+salda&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Please wait, fetching cities
# Retrieving weather data for arraial+do+cabo
# http://api.openweathermap.org/data/2.5/weather?q=arraial+do+cabo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for pringsewu
# http://api.openweathermap.org/data/2.5/weather?q=pringsewu&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for quang+ngai
# http://api.openweathermap.org/data/2.5/weather?q=quang+ngai&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bredasdorp
# http://api.openweathermap.org/data/2.5/weather?q=bredasdorp&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ust-kulom
# http://api.openweathermap.org/data/2.5/weather?q=ust-kulom&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for castro
# http://api.openweathermap.org/data/2.5/weather?q=castro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for thompson
# http://api.openweathermap.org/data/2.5/weather?q=thompson&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for carnarvon
# http://api.openweathermap.org/data/2.5/weather?q=carnarvon&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mairang
# http://api.openweathermap.org/data/2.5/weather?q=mairang&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for geraldton
# http://api.openweathermap.org/data/2.5/weather?q=geraldton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for millau
# http://api.openweathermap.org/data/2.5/weather?q=millau&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for sabha
# http://api.openweathermap.org/data/2.5/weather?q=sabha&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for takoradi
# http://api.openweathermap.org/data/2.5/weather?q=takoradi&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cidreira
# http://api.openweathermap.org/data/2.5/weather?q=cidreira&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for albany
# http://api.openweathermap.org/data/2.5/weather?q=albany&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for ponta+do+sol
# http://api.openweathermap.org/data/2.5/weather?q=ponta+do+sol&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for puerto+ayora
# http://api.openweathermap.org/data/2.5/weather?q=puerto+ayora&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for champasak
# http://api.openweathermap.org/data/2.5/weather?q=champasak&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bemidji
# http://api.openweathermap.org/data/2.5/weather?q=bemidji&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for tasiilaq
# http://api.openweathermap.org/data/2.5/weather?q=tasiilaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for marsa+matruh
# http://api.openweathermap.org/data/2.5/weather?q=marsa+matruh&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for siniscola
# http://api.openweathermap.org/data/2.5/weather?q=siniscola&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for nantucket
# http://api.openweathermap.org/data/2.5/weather?q=nantucket&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for rikitea
# http://api.openweathermap.org/data/2.5/weather?q=rikitea&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for punta+arenas
# http://api.openweathermap.org/data/2.5/weather?q=punta+arenas&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for busselton
# http://api.openweathermap.org/data/2.5/weather?q=busselton&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for novoilinsk
# http://api.openweathermap.org/data/2.5/weather?q=novoilinsk&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=51.7577815078&lon=108.65539495&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for viligili
# http://api.openweathermap.org/data/2.5/weather?q=viligili&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=0.542239750452&lon=73.2371699176&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for yellowknife
# http://api.openweathermap.org/data/2.5/weather?q=yellowknife&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cockburn+harbour
# http://api.openweathermap.org/data/2.5/weather?q=cockburn+harbour&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=22.3416263996&lon=-71.7444908848&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for le+vauclin
# http://api.openweathermap.org/data/2.5/weather?q=le+vauclin&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for banda+aceh
# http://api.openweathermap.org/data/2.5/weather?q=banda+aceh&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for emmett
# http://api.openweathermap.org/data/2.5/weather?q=emmett&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for loralai
# http://api.openweathermap.org/data/2.5/weather?q=loralai&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for port+hedland
# http://api.openweathermap.org/data/2.5/weather?q=port+hedland&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?q=bambanglipuro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for haimen
# http://api.openweathermap.org/data/2.5/weather?q=haimen&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for vardo
# http://api.openweathermap.org/data/2.5/weather?q=vardo&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for taolanaro
# http://api.openweathermap.org/data/2.5/weather?q=taolanaro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=-83.8860673724&lon=62.4140369429&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mezen
# http://api.openweathermap.org/data/2.5/weather?q=mezen&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for attawapiskat
# http://api.openweathermap.org/data/2.5/weather?q=attawapiskat&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Trying somewhere near that
# http://api.openweathermap.org/data/2.5/weather?lat=55.4975302428&lon=-86.4716762105&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for mahebourg
# http://api.openweathermap.org/data/2.5/weather?q=mahebourg&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for dakoro
# http://api.openweathermap.org/data/2.5/weather?q=dakoro&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for cape+town
# http://api.openweathermap.org/data/2.5/weather?q=cape+town&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for narsaq
# http://api.openweathermap.org/data/2.5/weather?q=narsaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for jamestown
# http://api.openweathermap.org/data/2.5/weather?q=jamestown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for georgetown
# http://api.openweathermap.org/data/2.5/weather?q=georgetown&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial
# Retrieving weather data for qaanaaq
# http://api.openweathermap.org/data/2.5/weather?q=qaanaaq&APPID=d77529b69cd743d50d241b93b6553ec5&units=imperial

# %%
#Combine data and export to csv
latitude_climate = pd.concat(frames)
latitude_climate.to_csv("climate.csv", header = True)
latitude_climate.head()
# Out:
#         Cities  Cloud Cover  Humidity   Latitude  Temperature  Wind Speed
# 0      rikitea           48        99 -57.795635        77.43       11.88
# 1   miraflores           12        84   1.118656        77.48        2.21
# 2     havelock            1       100  33.762181        50.05        3.89
# 3  east+london           90        93 -73.088838        64.40        4.70
# 4        nikki            0        55   9.735748        64.34        4.05

# %%
#Create scatter plots
# %pylab inline
pylab.rcParams['figure.figsize'] = (10, 6)
columns = list(latitude_climate.columns.values)
columns = [columns[1],columns[2],columns[4],columns[5]]
lats = latitude_climate["Latitude"]
counter = -1
for x in columns:
    counter = counter + 1
    plt.subplot(2,2,counter+1)
    column = columns[counter]
    y = latitude_climate[column]
    title = (column + "vs. Latitude")
    plt.scatter(lats, y, c=lats, cmap='viridis')
    plt.xlabel('Latitude')
    plt.ylabel(column)
    plt.title(column + " vs. Latitude")
plt.tight_layout(pad=0.4, w_pad=0.5, h_pad=1)
plt.show()
plt.savefig("graphs.png")
# Out:
# Populating the interactive namespace from numpy and matplotlib
# /Users/chelan/anaconda3/envs/python_data/lib/python3.5/site-packages/IPython/core/magics/pylab.py:160: UserWarning: pylab import has clobbered these variables: ['title']
# `%matplotlib` prevents importing * from pylab and numpy
#   "\n`%matplotlib` prevents importing * from pylab and numpy"

# %%
#Insights: 1) Very dry places (low humidity) are only present at high latitude. 
#2) High temperatures are clearly clustered around the equator.
#3) Extremely windy places are not typically by the equator.
